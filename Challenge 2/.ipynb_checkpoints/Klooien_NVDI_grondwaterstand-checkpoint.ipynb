# %%
import pandas, matplotlib.pyplot as plt, pylizard

# %%
df = pandas.read_csv('ndvi_stats_percelen.csv', sep=';', parse_dates=['date_num'])
df_gras = df.loc[df['gewasgroep']=='Grasland']

# %%
fig, ax = plt.subplots(figsize=[16, 9])
for i in df_gras['OBJECTID'].unique():
    x = df_gras.loc[df['OBJECTID']==i]['date_num']
    y = df_gras.loc[df['OBJECTID']==i]['MEAN']

    ax.plot(x, y)

# %%
nvdi = []
for i in df_gras['OBJECTID'].unique():
    x = list(df_gras.loc[df['OBJECTID']==i]['date_num'].values)
    y = df_gras.loc[df['OBJECTID']==i]['MEAN']

# %%
x, y, dist = 221345, 451589, 5000
df_peilbuizen = pylizard.pnt2buis(x, y, dist, report=True)
df_meting = df_peilbuizen.loc[(df_peilbuizen['uuid_hand']!='') | (df_peilbuizen['uuid_diver']!='')]

m = {}
for p in df_meting.iterrows():
    print(p[0])
    m[p[0]] = pylizard.Peilbuis(p[1]['buis'], p[1]['filt'], report=True)
# Out:
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=5000&point=6.354386713282765,52.04863709224236
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=5000&page=2&point=6.354386713282765%2C52.04863709224236
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=5000&page=3&point=6.354386713282765%2C52.04863709224236
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=5000&page=4&point=6.354386713282765%2C52.04863709224236
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=5000&page=5&point=6.354386713282765%2C52.04863709224236
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=5000&page=6&point=6.354386713282765%2C52.04863709224236
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=5000&page=7&point=6.354386713282765%2C52.04863709224236
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=5000&page=8&point=6.354386713282765%2C52.04863709224236
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=5000&page=9&point=6.354386713282765%2C52.04863709224236
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=5000&page=10&point=6.354386713282765%2C52.04863709224236
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=5000&page=11&point=6.354386713282765%2C52.04863709224236
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=5000&page=12&point=6.354386713282765%2C52.04863709224236
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=5000&page=13&point=6.354386713282765%2C52.04863709224236
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=5000&page=14&point=6.354386713282765%2C52.04863709224236
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=5000&page=15&point=6.354386713282765%2C52.04863709224236
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=5000&page=16&point=6.354386713282765%2C52.04863709224236
# B34C1033001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=B34C1033001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.338410803499527,52.096056637804566
# B34C0233001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=B34C0233001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.359257365530948,52.04802211254835
# 33H-0407001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=33H-0407001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.324896067474575,52.06675136050438
# 33H-1405001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=33H-1405001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.330183697422475,52.09140379064931
# 33HP0250002
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=33HP0250002
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.321907680209319,52.075955506664485
# 33HP0250001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=33HP0250001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.321907680209319,52.075955506664485
# 33HP0252001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=33HP0252001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.3048875932593855,52.055514546973626
# 33HP0252002
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=33HP0252002
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.3048875932593855,52.055514546973626
# 34C-0321001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34C-0321001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.340444485564844,52.05675439702348
# 34C-0323001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34C-0323001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.379967891350674,52.0773410326229
# 34C-0920001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34C-0920001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.401396999738942,52.065088379879306
# 34C-1033001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34C-1033001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.338410994791191,52.09606562481431
# 34C-1034001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34C-1034001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.38203681162271,52.07566884180645
# 34C-1036001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34C-1036001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.35351286548689,52.08539663480002
# 34C1146001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34C1146001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.358326081786222,52.078330448222474
# 34C-0025001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34C-0025001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.354317298264464,52.075043855118444
# 33H-0017001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=33H-0017001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.319298798519111,52.039671282401045
# 34C-1052001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34C-1052001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.37179268212446,52.099027254224225
# 40F-0487001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=40F-0487001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.33059988556076,52.023650687841275
# 40F-0487002
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=40F-0487002
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.33059988556076,52.023650687841275
# 34CL0083001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CL0083001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.379122255939032,52.03898691748275
# 34C1148002
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34C1148002
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.336080428972769,52.0898214910553
# 34C1148001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34C1148001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.336080428972769,52.0898214910553
# 34CL0084001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CL0084001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.383641369550753,52.036627327755525
# 34CL0085001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CL0085001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.387305895482872,52.03473181484443
# 34CL0094001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CL0094001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.362370303144364,52.04553991736913
# 34CP0077001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CP0077001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.344487880365086,52.055261737874886
# 34CP0107002
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CP0107002
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.375015100260142,52.04200336121622
# 34CP0107001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CP0107001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.375015100260142,52.04200336121622
# 34CP0045002
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CP0045002
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.354916667813485,52.042799519030154
# 34CP0045001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CP0045001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.354916667813485,52.042799519030154
# 34CL0058001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CL0058001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.352477145524278,52.05067025695172
# 34CL0063001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CL0063001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.362917010700279,52.03985026113255
# 34CP0120001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CP0120001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.381185329883315,52.059566990134506
# 34CP0120002
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CP0120002
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.381185329883315,52.059566990134506
# 40FP0301001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=40FP0301001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.317995095612552,52.0343108414822
# 40FP0301002
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=40FP0301002
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.317995095612552,52.0343108414822
# 41A-0266001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=41A-0266001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.395572813944206,52.02862463458346
# 34C-1041001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34C-1041001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.341689468727737,52.06571684040926
# 33HL9004001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=33HL9004001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.2989197474105705,52.048864427086784
# B34C0206001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=B34C0206001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.355789287985018,52.05658298145933
# 34CP9001001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CP9001001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.365374350734617,52.04905596674004
# 34CP9002001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CP9002001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.354916667813485,52.042799519030154
# 34CP0053001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CP0053001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.371279231952463,52.07097809916696
# 34CP0053002
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CP0053002
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.371279231952463,52.07097809916696
# 34CP0059001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34CP0059001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.342490189559989,52.03759765872889
# 41AL0047001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=41AL0047001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.3406371530392,52.03280383099418
# 41AP0101001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=41AP0101001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.384145095769137,52.013432201907406
# 41AP0101002
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=41AP0101002
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.384145095769137,52.013432201907406
# 34C1145001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=34C1145001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.403760069867561,52.04713386376502
# B34C0194001
# GET https://vitens.lizard.net/api/v3/locations/?code__icontains=B34C0194001
# GET https://vitens.lizard.net/api/v3/groundwaterstations/?dist=100&point=6.378919975129398,52.06895241029583

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy

fig, ax = plt.subplots(2, figsize=[16, 9], sharex=True)

h = {}
for k, v in m.items():
    #print(k, v)
    if v.uuid_diver!='':
        h = v.head_diver 
        h.loc[h<17].plot(label=k, ax=ax[0])

ax[0].set_xlabel('Datum')
ax[0].set_ylabel('Stijghoogte (m+N.A.P.)')

ax[0].set_xlim('2015', '2019')
ax[0].set_ylim(10, 17)

ax[0].xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax[0].xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))\

ax[0].set_yticks(numpy.arange(10, 17, 0.5))

ax[0].grid()

for i in df_gras['OBJECTID'].unique():
    x = df_gras.loc[df['OBJECTID']==i]['date_num']
    y = df_gras.loc[df['OBJECTID']==i]['MEAN']

    ax[1].plot(x, y)
    
plt.show();

# %%
list(y.values)
# Out:
# [203.59154929599998,
#  224.873239437,
#  225.070422535,
#  224.394366197,
#  218.18309859200002,
#  231.59154929599998,
#  184.5,
#  191.76056338,
#  216.85915493,
#  201.53521126799998,
#  213.436619718,
#  204.19718309900003,
#  184.985915493,
#  184.366197183,
#  182.056338028,
#  189.169014085,
#  201.957746479,
#  219.76056338,
#  180.78873239400002,
#  163.901408451,
#  199.14084507]
